# %% [markdown]
# <a href="https://colab.research.google.com/github/harshibhavanasi/FMML-LAB-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-10 06:14:19--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   279MB/s    in 0.2s
#
# 2023-05-10 06:14:21 (279 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 6118   1607.07195v2  Factorization machines (FMs) are a supervised ...  stat
# 22886  1710.01494v1  Deep convolutional neural networks (CNNs) base...  stat
# 21114  1708.02139v1  We release a dataset of 65646 StarCraft replay...    cs
# 5642   1505.06279v2  We discuss a general method to learn data repr...  stat
# 35138  cs/9901012v1  We study the following problem: given a class ...    cs
# ...             ...                                                ...   ...
# 6880   1707.01212v3  In this paper we propose an efficient algorith...  stat
# 10015  1607.00087v2  As a general means of expression, audio analys...    cs
# 23030  1802.04908v1  Modeling complex conditional distributions is ...  stat
# 23515   1304.1022v1  The study and development of software able to ...    cs
# 4523    0806.4341v1  The remarkable results of Foster and Vohra was...    cs
#
#                                                    title  year  \
# 6118                 Higher-Order Factorization Machines  2016
# 22886  Strengths and Weaknesses of Deep Learning Mode...  2017
# 21114          STARDATA: A StarCraft AI Research Dataset  2017
# 5642    The Benefit of Multitask Representation Learning  2015
# 35138  Extremal problems in logic programming and sta...  1999
# ...                                                  ...   ...
# 6880   ProtoDash: Fast Interpretable Prototype Selection  2017
# 10015  Fractal Dimension Pattern Based Multiresolutio...  2016
# 23030  Conditional Density Estimation with Bayesian N...  2018
# 23515  A software for aging faces applied to ancient ...  2013
# 4523        On Sequences with Non-Learnable Subsequences  2008
#
#                                                 keywords
# 6118   [factorization, supervised, combinations, dime...
# 22886  [convolutional, approaches, including, recogni...
# 21114  [starcraft, starcraft, suitability, classifica...
# 5642   [representations, justification, multitask, il...
# 35138  [following, determine, establish, characterize...
# ...                                                  ...
# 6880   [efficient, algorithm, protodash, selecting, p...
# 10015  [expression, recognition, attracted, attention...
# 23030  [conditional, distributions, tradition, condit...
# 23515  [development, recognition, technologies, solut...
# 4523   [remarkable, universal, randomized, forecastin...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6118     [factorization, supervised, combinations, dime...
# 22886    [convolutional, approaches, including, recogni...
# 21114    [starcraft, starcraft, suitability, classifica...
# 5642     [representations, justification, multitask, il...
# 35138    [following, determine, establish, characterize...
#                                ...
# 10838    [technology, measurable, activities, industrie...
# 22747    [diffusion, distribution, establish, diffusion...
# 18884    [increasing, applications, reasoning, uncertai...
# 23070    [extensively, dependecies, observations, regre...
# 11652    [clustering, frequently, clustering, community...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8929 words.
# Out of those 4611 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d5ddff28-1f9a-4026-a037-b5b7659c83af" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5ddff28-1f9a-4026-a037-b5b7659c83af")) {                    Plotly.newPlot(                        "d5ddff28-1f9a-4026-a037-b5b7659c83af",                        [{"x":["combinations","prediction","maintaining","arbitrary","algorithm","unfortunately","increasing","factorization","parameters","supervised","demonstrate","dimensional","different","efficient","algorithms","approaches","compression","techniques","currently","relatively","characteristics","weaknesses","artifacts","literature","considerable","information","significant","squeezenet","computation","descriptor","influence","degradations","convolutional","specifically","recognition","architectures","performance","including","detrimental","exploring","experimentation","architecture","verification","covariates","googlenet","comprehensive","occlusion","strengths","systematically","potential","investigate","brightness","improving","operating","corrupted","heuristics","reinforcement","available","imitation","classification","statistics","illustrate","furthermore","platforms","extraction","diversity","suitability","independent","reproducing","theoretical","representation","advantage","multitask","applications","important","dimensionality","multilayer","representations","beneficial","conditions","justification","particular","intrinsic","established","illustrated","determine","considering","described","establish","characterize","implication","procedure","disjunctive","following","programming","mandatory","negotiating","understanding","artificial","represents","biometric","disambiguated","formalization","completeness","enrollment","computational","partitioning","logically","consistency","consistent","benchmark","constraint","identifying","symmetries","exploiting","satisfaction","solutions","pathologists","correlated","combination","achieving","classifier","outperformed","providing","individually","correctly","quantitatively","corresponding","excluding","morphological","discrimination","separability","classifying","statistical","objective","histopathological","preparation","extracted","elimination","technique","extremely","modification","selection","optimality","efficiently","adversarial","placement","investigated","validation","perfomance","confirmed","optimization","significantly","overarching","integrals","parametric","similarity","principle","estimation","challenging","classifiers","extension","functions","informations","multimedia","maximizing","precision","misclassification","naturally","procedures","generally","quadratic","multimodal","considered","attention","preserving","characterization","simultaneous","visibility","inference","introduced","dimension","orientation","monocular","outperforms","experiments","localization","detection","probability","recurrent","employing","summaries","transformation","threshold","probabilistic","predicting","synthetic","relationship","leveraging","completion"],"y":[38,227,31,78,801,38,98,36,243,173,542,195,771,413,572,400,50,377,61,55,96,20,27,142,41,753,236,1,161,24,50,3,386,184,383,121,879,234,2,36,13,251,47,2,3,59,28,21,20,136,145,8,99,37,16,41,117,332,13,479,56,72,158,25,133,49,8,126,15,158,378,102,11,447,353,54,11,216,21,138,8,281,36,51,10,62,66,72,43,46,7,115,8,89,128,2,2,174,144,54,10,4,6,9,4,302,17,3,52,97,219,96,65,7,81,26,151,3,36,145,63,139,22,85,16,27,28,152,3,28,21,8,40,154,178,4,3,112,16,255,36,28,145,24,145,100,9,61,52,1,8,345,259,2,4,43,140,46,197,240,100,86,214,3,8,27,67,11,59,38,85,34,30,135,149,41,22,20,6,215,137,62,28,20,264,635,72,322,188,148,26,10,61,34,150,83,138,71,51,30],"type":"bar"},{"x":["combinations","prediction","maintaining","arbitr ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4611,), (4611, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.805

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Block</span> <span style=''>matching</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>motion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.4845360824742268);'>Artificial</span> <span style=''>Bee</span> <span style=''>Colony</span> <span style=''>(ABC)</span> <br/><br/><span style=''>Block</span> <span style=''>matching</span> <span style=''>(BM)</span> <span style=''>motion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>plays</span> <span style=''>a</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>role</span> <span style=''>in</span> <span style=''>video</span> <span style=''>coding</span> <span style=''>In</span> <span style=''>a</span> <span style=''>BM</span> <span style=''>approach</span> <span style=''>image</span> <span style=''>frames</span> <span style=''>in</span> <span style=''>a</span> <span style=''>video</span> <span style=''>sequence</span> <span style=''>are</span> <span style=''>divided</span> <span style=''>into</span> <span style=''>blocks</span> <span style=''>For</span> <span style=''>each</span> <span style=''>block</span> <span style=''>in</span> <span style=''>the</span> <span style=''>current</span> <span style=''>frame</span> <span style=''>the</span> <span style=''>best</span> <span style=''>matching</span> <span style=''>block</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.31645569620253167);'>identified</span> <span style=''>inside</span> <span style=''>a</span> <span style=''>region</span> <span style=''>of</span> <span style=''>the</span> <span style=''>previous</span> <span style=''>frame</span> <span style=''>aiming</span> <span style=''>to</span> <span style=''>minimize</span> <span style=''>the</span> <span style=''>sum</span> <span style=''>of</span> <span style=''>absolute</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differences</span> <span style=''>(SAD)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Unfortunately</span> <span style=''>the</span> <span style=''>SAD</span> <span style='background-color:rgba(0, 255, 0, 0.4578947368421052);'>evaluation</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expensive</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represents</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consuming</span> <span style='background-color:rgba(0, 255, 0, 0.5333333333333333);'>operation</span> <span style=''>in</span> <span style=''>the</span> <span style=''>BM</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.34177215189873406);'>Therefore</span> <span style=''>BM</span> <span style=''>motion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>approached</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>where</span> <span style=''>the</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>find</span> <span style=''>the</span> <span style=''>best</span> <span style=''>matching</span> <span style=''>block</span> <span style=''>within</span> <span style=''>a</span> <span style=''>search</span> <span style=''>space</span> <span style=''>The</span> <span style=''>simplest</span> <span style='background-color:rgba(0, 255, 0, 0.3551020 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>model</span> <span style=''>with</span> <span style=''>a</span> <span style=''>hidden</span> <span style=''>logistic</span> <span style=''>process</span> <span style=''>for</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extraction</span> <span style=''>from</span> <span style=''>time</span> <span style=''>series</span> <br/><br/><span style=''>A</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extraction</span> <span style=''>from</span> <span style=''>time</span> <span style=''>series</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>This</span> <span style=''>approach</span> <span style=''>consists</span> <span style=''>of</span> <span style=''>a</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporating</span> <span style=''>a</span> <span style=''>discrete</span> <span style=''>hidden</span> <span style=''>logistic</span> <span style=''>process</span> <span style=''>The</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>by</span> <span style=''>the</span> <span style=''>maximum</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dedicated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Maximization</span> <span style=''>(EM)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>the</span> <span style=''>hidden</span> <span style=''>logistic</span> <span style=''>process</span> <span style=''>in</span> <span style=''>the</span> <span style=''>inner</span> <span style=''>loop</span> <span style=''>of</span> <span style=''>the</span> <span style=''>EM</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>using</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>class</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Iterative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Reweighted</span> <span style=''>Least</span> <span style=''>Squares</span> <span style=''>(IRLS)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>piecewise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style=''>variant</span> <span style=''>have</span> <span style=''>also</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparisons</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>study</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Recursive</span> <span style=''>Sampling</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Nyström</span> <span style=''>Method</span> <br/><br/><span style=''>We</span> <span style=''>give</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>kernel</span> <span style=''>Nystrom</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>that</span> <span style=''>runs</span> <span style=''>in</span> <span style=''>linear</span> <span style=''>time</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>training</span> <span style=''>points</span> <span style=''>and</span> <span style=''>is</span> <span style=''>provably</span> <span style=''>accurate</span> <span style=''>for</span> <span style=''>all</span> <span style=''>kernel</span> <span style=''>matrices</span> <span style=''>without</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>dependence</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>regularity</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>incoherence</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>projects</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>onto</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>s</span> <span style=''>landmark</span> <span style=''>points</span> <span style=''>sampled</span> <span style=''>by</span> <span style=''>their</span> <span style=''>ridge</span> <span style=''>leverage</span> <span style=''>scores</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requiring</span> <span style=''>just</span> <span style=''>O(ns)</span> <span style=''>kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>evaluations</span> <span style=''>and</span> <span style=''>O(ns2)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style=''>runtime</span> <span style=''>While</span> <span style=''>leverage</span> <span style=''>score</span> <span style=''>sampling</span> <span style=''>has</span> <span style=''>long</span> <span style=''>been</span> <span style=''>known</span> <span style=''>to</span> <span style=''>give</span> <span style=''>strong</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>for</span> <span style=''>Nystrom</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>employing</span> <span style=''>a</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recursive</span> <span style=''>sampling</span> <span style=''>scheme</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>to</span> <span style=''>make</span> <span style=''>the</span> <span style=''>approach</span> <span style=''>scalable</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Empirically</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>it</span> <span style=''>finds</span> <span style=''>more</span> <span style=''>accurate</span> <span style=''>lower</span> <span style=''>rank</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.4080 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Evaluation</span> <span style=''>of</span> <span style=''>Feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>Methods</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Mutual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Information</span> <br/><br/><span style=''>Feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>usually</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluated</span> <span style=''>by</span> <span style=''>wrapping</span> <span style=''>specific</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>and</span> <span style=''>datasets</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>very</span> <span style=''>often</span> <span style=''>in</span> <span style=''>unfair</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparisons</span> <span style=''>between</span> <span style=''>methods</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>that</span> <span style=''>allows</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>obtaining</span> <span style=''>the</span> <span style=''>true</span> <span style=''>feature</span> <span style=''>ordering</span> <span style=''>of</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>forward</span> <span style=''>feature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>methods</span> <span style=''>based</span> <span style=''>on</span> <span style=''>mutual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>of</span> <span style=''>entropy</span> <span style=''>or</span> <span style=''>mutual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>or</span> <span style=''>datasets</span> <span style=''>and</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>an</span> <span style=''>undoubtful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>of</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>Moreover</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>unveils</span> <span style=''>problems</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrinsic</span> <span style=''>to</span> <span style=''>some</span> <span style=''>methods</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>otherwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>namely</span> <span style='background-color:rgba(255, 0,  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09889325240985362)
# 	representation (0.13495180292752587)
# 	architecture (0.08961085326669047)
# 	processing (0.11067475901463764)
# 	detection (0.11495894323455909)
# 	segmentation (0.07747233131024633)
# 	information (0.2688325598000714)
# 	recognition (0.13673687968582648)
# 	convolutional (0.13780792574080686)
# 	different (0.2752588361299536)
#
# Some Statistics words are:
# 	theoretical (0.13706853426713356)
# 	algorithms (0.28864432216108055)
# 	estimation (0.16208104052026012)
# 	algorithm (0.38219109554777386)
# 	variables (0.14157078539269635)
# 	distribution (0.1805902951475738)
# 	statistical (0.16108054027013508)
# 	inference (0.1905952976488244)
# 	dimensional (0.18359179589794897)
# 	regression (0.1805902951475738)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5eda4ed2-de93-4144-ab6f-ac71a2fffd3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5eda4ed2-de93-4144-ab6f-ac71a2fffd3c")) {                    Plotly.newPlot(                        "5eda4ed2-de93-4144-ab6f-ac71a2fffd3c",                        [{"x":["combinations","prediction","maintaining","arbitrary","algorithm","unfortunately","increasing","factorization","parameters","supervised","demonstrate","dimensional","different","efficient","algorithms","approaches","compression","techniques","currently","relatively","characteristics","weaknesses","artifacts","literature","considerable","information","significant","squeezenet","computation","descriptor","influence","degradations","convolutional","specifically","recognition","architectures","performance","including","detrimental","exploring","experimentation","architecture","verification","covariates","googlenet","comprehensive","occlusion","strengths","systematically","potential","investigate","brightness","improving","operating","corrupted","heuristics","reinforcement","available","imitation","classification","statistics","illustrate","furthermore","platforms","extraction","diversity","suitability","independent","reproducing","theoretical","representation","advantage","multitask","applications","important","dimensionality","multilayer","representations","beneficial","conditions","justification","particular","intrinsic","established","illustrated","determine","considering","described","establish","characterize","implication","procedure","disjunctive","following","programming","mandatory","negotiating","understanding","artificial","represents","biometric","disambiguated","formalization","completeness","enrollment","computational","partitioning","logically","consistency","consistent","benchmark","constraint","identifying","symmetries","exploiting","satisfaction","solutions","pathologists","correlated","combination","achieving","classifier","outperformed","providing","individually","correctly","quantitatively","corresponding","excluding","morphological","discrimination","separability","classifying","statistical","objective","histopathological","preparation","extracted","elimination","technique","extremely","modification","selection","optimality","efficiently","adversarial","placement","investigated","validation","perfomance","confirmed","optimization","significantly","overarching","integrals","parametric","similarity","principle","estimation","challenging","classifiers","extension","functions","informations","multimedia","maximizing","precision","misclassification","naturally","procedures","generally","quadratic","multimodal","considered","attention","preserving","characterization","simultaneous","visibility","inference","introduced","dimension","orientation","monocular","outperforms","experiments","localization","detection","probability","recurrent","employing","summaries","transformation","threshold","probabilistic","predicting","synthetic","relationship","leveraging","completion","implementation","sequences","decomposition","magnitude","structure","incremental","advantages","arguments","guarantees","promising","environment","generalized","applicability","approximate","numerical","alternative","successfully","iteration","approximated","guarantee","engineering","segmentation","incorporate","framework","interests","alleviate","character","attracted","effectiveness","performances","embeddings","efficiency","experimental","hierarchical","clustering","hierarchies","processes","structured","nonparametric","posterior","unbounded","diffusion","unobserved","dependency","exchangeable","components","distribution","evolutionary","infinitely","aggregated","languages","restaurants","tripadvisor","in ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	underdetermined
# 	nucleotide
# 	sparsistent
# 	encounters
# 	physiologic
# 	hypernetworks
# 	hypernetwork
# 	electroencephalography
# 	unmeasured
# 	refitting
# 	incurring
# 	alliterative
# 	langlands
# 	ferromagnetic
# 	favourable
# 	idealized
# 	interchangeable
# 	tightening
# 	exogenous
# 	endogenous
# Some words which never appear in Statistics papers:
# 	disjunctive
# 	disambiguated
# 	logically
# 	histopathological
# 	visibility
# 	monocular
# 	tripadvisor
# 	morphologically
# 	unannotated
# 	apparently
# 	resourced
# 	constancy
# 	psychological
# 	surpassed
# 	collaborations
# 	possibilistic
# 	attenuation
# 	radiotherapy
# 	appreciation
# 	quintessential

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.06550994757978e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
